# %% [markdown]
# <P> <img src="https://i.ibb.co/gyNf19D/nhslogo.png" alt="nhslogo" border="0" width="100" align="right"><font size="6"><b> CS4132 Data Analytics</b> </font>

# %% [markdown]
# # Lab 3.2: Pandas

# %% [markdown]
# ## (Section 3.4) Manipulating Dataframe

# %% [markdown]
# Complete the following questions and upload your `.ipynb` file to Coursemology.
#
# Name the file in the following format:
#
# `Lab<Num><YourName>.ipynb`

# %% [markdown]
# ### Q1

# %% [markdown]
# We will use the wine data as discussed in the notes for this lab.

# %%
import pandas as pd
reviews = pd.read_csv("wine.csv", index_col=0) #read in data from wine.csv
reviews.head() #display the first few data from the dataframe
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# a) Select the first value from the description column of `reviews` and update it to `"The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity"`. Show that the data has been updated.

# %%
#your solution
reviews.loc[0, 'description'] = "The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity"
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  The palate isn't overly expressive, offering u...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# b) Select the records with index labels `1`, `2`, `3`, `5`, and `8`. Update the points of all these records to 90. Show that the data has been updated.

# %%
#your solution
reviews.loc[[1, 2, 3, 4, 5, 8], 'points'] = 90
reviews.iloc[[1, 2, 3, 4, 5, 8]]
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
# 5     Spain  Blackberry and raspberry aromas show a typical...
# 8   Germany  Savory dried thyme notes accent sunnier flavor...
#
#                           designation  points  price        province  \
# 1                            Avidagos      90   15.0           Douro
# 2                                 NaN      90   14.0          Oregon
# 3                Reserve Late Harvest      90   13.0        Michigan
# 4  Vintner's Reserve Wild Child Block      90   65.0          Oregon
# 5                        Ars In Vitro      90   15.0  Northern Spain
# 8                               Shine      90   12.0     Rheinhessen
#
#               region_1           region_2         taster_name  \
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
# 5              Navarra                NaN   Michael Schachner
# 8                  NaN                NaN  Anna Lee C. Iijima
#
#   taster_twitter_handle                                              title  \
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 5           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# 8                   NaN  Heinz Eifel 2013 Shine Gewürztraminer (Rheinhe...
#
#               variety               winery
# 1      Portuguese Red  Quinta dos Avidagos
# 2          Pinot Gris            Rainstorm
# 3            Riesling           St. Julian
# 4          Pinot Noir         Sweet Cheeks
# 5  Tempranillo-Merlot               Tandem
# 8      Gewürztraminer          Heinz Eifel

# %% [markdown]
# c) For all wines where region_1 is a "Valley", increase the price by 5.

# %%
#your solutio
reviews.loc[reviews.region_1.notnull() & reviews.region_1.str.contains('Valley'), 'price'] += 5
reviews.loc[reviews.region_1.notnull() & reviews.region_1.str.contains('Valley')]
# Out:
#    country                                        description  \
# 2       US  Tart and snappy, the flavors of lime flesh and...
# 4       US  Much like the regular bottling from 2012, this...
# 10      US  Soft, supple plum envelopes an oaky structure ...
# 12      US  Slightly reduced, this wine offers a chalky, t...
# 33      US  Rustic and dry, this has flavors of berries, c...
# 34      US  This shows a tart, green gooseberry flavor tha...
# 41      US  A stiff, tannic wine, this slowly opens and br...
# 55      US  This shows jelly-like flavors of orange and pe...
# 59      US  Aromas of cranberry, barrel spice and herb are...
# 60      US  Syrupy and dense, this wine is jammy in plum a...
# 62      US  The aromas are brooding, with notes of barrel ...
# 64      US  There are intriguing touches to the nose of th...
# 67      US  A blend of Merlot and Cabernet Franc, this win...
# 70      US  Aromas of vanilla, char and toast lead to ligh...
# 71      US  Big oak defines this robustly dense and extrac...
# 75      US  This is made from equal parts Cabernet Franc a...
# 84      US  A healthy addition of 13% Petite Sirah provide...
# 87      US  Softened tannins surround a light-bodied, lean...
# 92      US  All red Bordeaux varieties are represented in ...
# 94      US  Barrel notes are prominent, with aromas of Cre...
# 99      US  This blends 20% each of all five red-Bordeaux ...
#
#                                 designation  points  price    province  \
# 2                                       NaN      90   19.0      Oregon
# 4        Vintner's Reserve Wild Child Block      90   70.0      Oregon
# 10                           Mountain Cuvée      87   24.0  California
# 12                                      NaN      87   39.0  California
# 33                    Puma Springs Vineyard      86   55.0  California
# 34                                      NaN      86   25.0  California
# 41                                      NaN      86   27.0      Oregon
# 55                           Estate Bottled      85   35.0  California
# 59                                      NaN      86   60.0  Washington
# 60                                   Estate      86  105.0  California
# 62                     Alder Ridge Vineyard      86   30.0  Washington
# 64                              Golden Horn      86   31.0  California
# 67                                 Inspired      86   51.0  Washington
# 70                                      NaN      86   17.0  Washington
# 71                                 Old Vine      86   45.0  California
# 75                               The Cypher      86   80.0  California
# 84                                  Classic      86   29.0  California
# 87                           Blau Vineyards      86   60.0  California
# 92                               Magnificat      88   60.0  California
# 94  Grand Klasse Reserve Lawrence Vineyards      88   27.0  Washington
# 99              Intreccio Library Selection      88   80.0  California
#
#                 region_1           region_2       taster_name  \
# 2      Willamette Valley  Willamette Valley      Paul Gregutt
# 4      Willamette Valley  Willamette Valley      Paul Gregutt
# 10           Napa Valley               Napa    Virginie Boone
# 12      Alexander Valley             Sonoma    Virginie Boone
# 33      Dry Creek Valley             Sonoma               NaN
# 34         Sonoma Valley             Sonoma               NaN
# 41     Willamette Valley  Willamette Valley      Paul Gregutt
# 55           Napa Valley               Napa               NaN
# 59  Columbia Valley (WA)    Columbia Valley  Sean P. Sullivan
# 60           Napa Valley               Napa    Virginie Boone
# 62  Columbia Valley (WA)    Columbia Valley  Sean P. Sullivan
# 64     Santa Ynez Valley      Central Coast     Matt Kettmann
# 67  Columbia Valley (WA)    Columbia Valley  Sean P. Sullivan
# 70  Columbia Valley (WA)    Columbia Valley  Sean P. Sullivan
# 71      Alexander Valley             Sonoma    Virginie Boone
# 75           Napa Valley               Napa    Virginie Boone
# 84           Napa Valley               Napa    Virginie Boone
# 87        Knights Valley             Sonoma    Virginie Boone
# 92           Napa Valley               Napa    Virginie Boone
# 94  Columbia Valley (WA)    Columbia Valley  Sean P. Sullivan
# 99           Napa Valley               Napa    Virginie Boone
#
#    taster_twitter_handle                                              title  \
# 2            @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 4            @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 10               @vboone  Kirkland Signature 2011 Mountain Cuvée Caberne...
# 12               @vboone  Louis M. Martini 2012 Cabernet Sauvignon (Alex...
# 33                   NaN  Envolve 2010 Puma Springs Vineyard Red (Dry Cr...
# 34                   NaN       Envolve 2011 Sauvignon Blanc (Sonoma Valley)
# 41           @paulgwine   Hawkins Cellars 2009 Pinot Noir (Willamette Va...
# 55                   NaN  RustRidge 2010 Estate Bottled Chardonnay (Napa...
# 59         @wawinereport       Mellisoni 2014 Malbec (Columbia Valley (WA))
# 60               @vboone  Okapi 2013 Estate Cabernet Sauvignon (Napa Val...
# 62         @wawinereport  Ram 2014 Alder Ridge Vineyard Cabernet Franc (...
# 64         @mattkettmann  Sevtap 2015 Golden Horn Sauvignon Blanc (Santa...
# 67         @wawinereport  Basel Cellars 2013 Inspired Red (Columbia Vall...
# 70         @wawinereport  Drumheller 2014 Chardonnay (Columbia Valley (WA))
# 71               @vboone  Eco Terreno 2013 Old Vine Cabernet Sauvignon (...
# 75               @vboone  Mulvane Wine Co. 2013 The Cypher Red (Napa Val...
# 84               @vboone  Napa Cellars 2014 Classic Zinfandel (Napa Valley)
# 87               @vboone  Passaggio 2014 Blau Vineyards Merlot (Knights ...
# 92               @vboone  Franciscan 2013 Magnificat Meritage (Napa Valley)
# 94         @wawinereport  Gård 2014 Grand Klasse Reserve Lawrence Vineya...
# 99               @vboone  Soquel Vineyards 2013 Intreccio Library Select...
#
#                      variety              winery
# 2                 Pinot Gris           Rainstorm
# 4                 Pinot Noir        Sweet Cheeks
# 10        Cabernet Sauvignon  Kirkland Signature
# 12        Cabernet Sauvignon    Louis M. Martini
# 33                 Red Blend             Envolve
# 34           Sauvignon Blanc             Envolve
# 41                Pinot Noir     Hawkins Cellars
# 55                Chardonnay           RustRidge
# 59                    Malbec           Mellisoni
# 60        Cabernet Sauvignon               Okapi
# 62            Cabernet Franc                 Ram
# 64           Sauvignon Blanc              Sevtap
# 67  Bordeaux-style Red Blend       Basel Cellars
# 70                Chardonnay          Drumheller
# 71        Cabernet Sauvignon         Eco Terreno
# 75  Bordeaux-style Red Blend    Mulvane Wine Co.
# 84                 Zinfandel        Napa Cellars
# 87                    Merlot           Passaggio
# 92                  Meritage          Franciscan
# 94                  Viognier                Gård
# 99  Bordeaux-style Red Blend    Soquel Vineyards

# %% [markdown]
# d) Split the taster name into first name and last name. Finally update taster name to be the first name only.

# %%
#your solution
reviews.loc[:, 'taster_name'] = reviews.loc[:, 'taster_name'].str.split(' ').str.get(0)
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  The palate isn't overly expressive, offering u...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      90   15.0              Douro
# 2                                 NaN      90   19.0             Oregon
# 3                Reserve Late Harvest      90   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      90   70.0             Oregon
#
#               region_1           region_2 taster_name taster_twitter_handle  \
# 0                 Etna                NaN       Kerin          @kerinokeefe
# 1                  NaN                NaN       Roger            @vossroger
# 2    Willamette Valley  Willamette Valley        Paul           @paulgwine
# 3  Lake Michigan Shore                NaN   Alexander                   NaN
# 4    Willamette Valley  Willamette Valley        Paul           @paulgwine
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %% [markdown]
# e) Find all wines tasted by taster whose first name is 5 characters long.

# %%
#your solution
reviews[reviews.taster_name.str.split(' ').str.get(0).str.len() == 5]
# Out:
#      country                                        description  \
# 0      Italy  The palate isn't overly expressive, offering u...
# 1   Portugal  This is ripe and fruity, a wine that is smooth...
# 6      Italy  Here's a bright, informal red that opens with ...
# 7     France  This dry and restrained wine offers spice in p...
# 9     France  This has great depth of flavor with its fresh ...
# 11    France  This is a dry wine, very spicy, with a tight, ...
# 13     Italy  This is dominated by oak and oak-driven aromas...
# 22     Italy  Delicate aromas recall white flower and citrus...
# 24     Italy  Aromas of prune, blackcurrant, toast and oak c...
# 26     Italy  Pretty aromas of yellow flower and stone fruit...
# 27     Italy  Aromas recall ripe dark berry, toast and a whi...
# 28     Italy  Aromas suggest mature berry, scorched earth, a...
# 30    France  Red cherry fruit comes laced with light tannin...
# 42    France  This is a festive wine, with soft, ripe fruit ...
# 49    France  Soft and fruity, this is a generous, ripe wine...
# 53    France  Fruity and lightly herbaceous, this has fine t...
# 61     Italy  This densely hued wine has aromas of black plu...
# 63    France  This fat, yeasty Champagne is comprised predom...
# 65    France  From the warm 2015 vintage, this is a soft and...
# 66    France  This soft, rounded wine is ripe with generous ...
# 69    France  This cooperative, based in Aÿ, has benefited f...
# 72     Italy  Aromas of black-skinned fruit, leather, underb...
# 79  Portugal  Grown on the sandy soil of Tejo, the wine is t...
# 82    France  This fruity, sweet wine is immediately attract...
# 88     Italy  Subdued aromas of French oak, toast and acacia...
# 89     Italy  Made primarily from Sangiovese, with some Malv...
# 95    France  This is a dense wine, packed with both tannins...
# 96    France  The wine comes from one of the cru estates fol...
# 98     Italy  Forest floor, menthol, espresso, cranberry and...
#
#             designation  points  price           province  \
# 0          Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1              Avidagos      90   15.0              Douro
# 6               Belsito      87   16.0  Sicily & Sardinia
# 7                   NaN      87   24.0             Alsace
# 9           Les Natures      87   27.0             Alsace
# 11                  NaN      87   30.0             Alsace
# 13                Rosso      87    NaN  Sicily & Sardinia
# 22            Ficiligno      87   19.0  Sicily & Sardinia
# 24                Aynat      87   35.0  Sicily & Sardinia
# 26               Dalila      87   13.0  Sicily & Sardinia
# 27                  NaN      87   10.0  Sicily & Sardinia
# 28   Mascaria Barricato      87   17.0  Sicily & Sardinia
# 30              Nouveau      86    NaN         Beaujolais
# 42              Nouveau      86    9.0         Beaujolais
# 49           Eté Indien      86   14.0         Beaujolais
# 53    La Fleur d'Amélie      85   15.0           Bordeaux
# 61             Prugneto      86   17.0      Central Italy
# 63            Brut Rosé      86   58.0          Champagne
# 65                  NaN      86   24.0           Burgundy
# 66                  NaN      86   15.0           Burgundy
# 69            Brut Rosé      86   55.0          Champagne
# 72           Daginestra      86   32.0     Southern Italy
# 79               Bridão      86    NaN               Tejo
# 82           La Réserve      86   11.0       France Other
# 88  Le Mandorle Riserva      86   29.0            Tuscany
# 89                  NaN      88   19.0            Tuscany
# 95                  NaN      88   20.0         Beaujolais
# 96                  NaN      88   18.0         Beaujolais
# 98         Dono Riserva      88   30.0            Tuscany
#
#                       region_1 region_2 taster_name taster_twitter_handle  \
# 0                         Etna      NaN       Kerin          @kerinokeefe
# 1                          NaN      NaN       Roger            @vossroger
# 6                     Vittoria      NaN       Kerin          @kerinokeefe
# 7                       Alsace      NaN       Roger            @vossroger
# 9                       Alsace      NaN       Roger            @vossroger
# 11                      Alsace      NaN       Roger            @vossroger
# 13                        Etna      NaN       Kerin          @kerinokeefe
# 22                     Sicilia      NaN       Kerin          @kerinokeefe
# 24                     Sicilia      NaN       Kerin          @kerinokeefe
# 26             Terre Siciliane      NaN       Kerin          @kerinokeefe
# 27             Terre Siciliane      NaN       Kerin          @kerinokeefe
# 28       Cerasuolo di Vittoria      NaN       Kerin          @kerinokeefe
# 30         Beaujolais-Villages      NaN       Roger            @vossroger
# 42                  Beaujolais      NaN       Roger            @vossroger
# 49                    Brouilly      NaN       Roger            @vossroger
# 53              Bordeaux Blanc      NaN       Roger            @vossroger
# 61                     Romagna      NaN       Kerin          @kerinokeefe
# 63                   Champagne      NaN       Roger            @vossroger
# 65                     Chablis      NaN       Roger            @vossroger
# 66       Mâcon-Milly Lamartine      NaN       Roger            @vossroger
# 69                   Champagne      NaN       Roger            @vossroger
# 72       Aglianico del Vulture      NaN       Kerin          @kerinokeefe
# 79                         NaN      NaN       Roger            @vossroger
# 82               Vin de France      NaN       Roger            @vossroger
# 88  Vernaccia di San Gimignano      NaN       Kerin          @kerinokeefe
# 89                     Toscana      NaN       Kerin          @kerinokeefe
# 95                    Juliénas      NaN       Roger            @vossroger
# 96                      Régnié      NaN       Roger            @vossroger
# 98       Morellino di Scansano      NaN       Kerin          @kerinokeefe
#
#                                                 title  \
# 0                   Nicosia 2013 Vulkà Bianco  (Etna)
# 1       Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 6    Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# 7               Trimbach 2012 Gewurztraminer (Alsace)
# 9   Jean-Baptiste Adam 2012 Les Natures Pinot Gris...
# 11            Leon Beyer 2012 Gewurztraminer (Alsace)
# 13             Masseria Setteporte 2012 Rosso  (Etna)
# 22  Baglio di Pianetto 2007 Ficiligno White (Sicilia)
# 24        Canicattì 2009 Aynat Nero d'Avola (Sicilia)
# 26       Stemmari 2013 Dalila White (Terre Siciliane)
# 27       Stemmari 2013 Nero d'Avola (Terre Siciliane)
# 28  Terre di Giurfo 2011 Mascaria Barricato  (Cera...
# 30  Domaine de la Madone 2012 Nouveau  (Beaujolais...
# 42             Henry Fessy 2012 Nouveau  (Beaujolais)
# 49   Vignerons de Bel Air 2011 Eté Indien  (Brouilly)
# 53  Château de Sours 2011 La Fleur d'Amélie  (Bord...
# 61  Podere dal Nespoli 2015 Prugneto Sangiovese (R...
# 63          Roland Champion NV Brut Rosé  (Champagne)
# 65                      Simonnet-Febvre 2015  Chablis
# 66  Vignerons des Terres Secrètes 2015  Mâcon-Mill...
# 69                   Collet NV Brut Rosé  (Champagne)
# 72  Grifalco 2013 Daginestra  (Aglianico del Vulture)
# 79  Adega Cooperativa do Cartaxo 2014 Bridão Touri...
# 82  Lionel Osmin & Cie 2016 La Réserve Petit Manse...
# 88  Poggio Alloro 2014 Le Mandorle Riserva  (Verna...
# 89               Fattoria Sardi 2015 Rosato (Toscana)
# 95                         Henry Fessy 2015  Juliénas
# 96                           Henry Fessy 2015  Régnié
# 98  Serpaia di Endrizzi 2010 Dono Riserva  (Morell...
#
#                        variety                         winery
# 0                  White Blend                        Nicosia
# 1               Portuguese Red            Quinta dos Avidagos
# 6                     Frappato                Terre di Giurfo
# 7               Gewürztraminer                       Trimbach
# 9                   Pinot Gris             Jean-Baptiste Adam
# 11              Gewürztraminer                     Leon Beyer
# 13           Nerello Mascalese            Masseria Setteporte
# 22                 White Blend             Baglio di Pianetto
# 24                Nero d'Avola                      Canicattì
# 26                 White Blend                       Stemmari
# 27                Nero d'Avola                       Stemmari
# 28                   Red Blend                Terre di Giurfo
# 30                       Gamay           Domaine de la Madone
# 42                       Gamay                    Henry Fessy
# 49                       Gamay           Vignerons de Bel Air
# 53  Bordeaux-style White Blend               Château de Sours
# 61                  Sangiovese             Podere dal Nespoli
# 63             Champagne Blend                Roland Champion
# 65                  Chardonnay                Simonnet-Febvre
# 66                  Chardonnay  Vignerons des Terres Secrètes
# 69             Champagne Blend                         Collet
# 72                   Aglianico                       Grifalco
# 79            Touriga Nacional   Adega Cooperativa do Cartaxo
# 82               Petit Manseng             Lionel Osmin & Cie
# 88                   Vernaccia                  Poggio Alloro
# 89                      Rosato                 Fattoria Sardi
# 95                       Gamay                    Henry Fessy
# 96                       Gamay                    Henry Fessy
# 98                  Sangiovese            Serpaia di Endrizzi

# %% [markdown]
# ### Q2

# %% [markdown]
# Complete the following questions using the sample DataFrame given:

# %%
data = pd.DataFrame({"col1": range(3),"col2": range(3,6)})
data
# Out:
#    col1  col2
# 0     0     3
# 1     1     4
# 2     2     5

# %% [markdown]
# a) Insert a third column, named col3, with entries 6, 9, 10

# %%
#your solution
data.insert(2, 'col3', [6, 9, 10])
data
# Out:
#    col1  col2  col3
# 0     0     3     6
# 1     1     4     9
# 2     2     5    10

# %% [markdown]
# b) Insert a forth row with entries 5.

# %%
#your solution
data = pd.concat([data, pd.DataFrame([[5, 5, 5]], columns=['col1', 'col2', 'col3'])], ignore_index=True)
data
# Out:
#    col1  col2  col3
# 0     0     3     6
# 1     1     4     9
# 2     2     5    10
# 3     5     5     5

# %% [markdown]
# c) Swap the data in col2 and col1.

# %%
#your solution
temp = data['col1'].copy()
data['col1'] = data['col2']
data['col2'] = temp
data
# Out:
#    col1  col2  col3
# 0     3     0     6
# 1     4     1     9
# 2     5     2    10
# 3     5     5     5

# %% [markdown]
# d) Drop the rows 1 and 2.

# %%
#your solution
data.drop([1, 2])
# Out:
#    col1  col2  col3
# 0     3     0     6
# 3     5     5     5

# %% [markdown]
# e) Divide the elements in row 1 by the elements in row 2. Insert the result as a new row in the dataframe as the first row.

# %%
#your solution
temp = [data.iloc[1] / data.iloc[2]]
data = pd.concat([data, pd.DataFrame(temp, columns=['col1', 'col2', 'col3'])], ignore_index=True)
data
# Out:
#    col1  col2  col3
# 0   3.0   0.0   6.0
# 1   4.0   1.0   9.0
# 2   5.0   2.0  10.0
# 3   5.0   5.0   5.0
# 4   0.8   0.5   0.9

# %% [markdown]
# ### Q3

# %% [markdown]
# Complete the following questions using the sample DataFrame given:

# %%
df1 = pd.DataFrame({'name': ['Peter', 'Paul', 'Mary'],
                    'food': ['fish', 'beans', 'bread']},
                   columns=['name', 'food'])
df1
# Out:
#     name   food
# 0  Peter   fish
# 1   Paul  beans
# 2   Mary  bread

# %%
df2 = pd.DataFrame({'cusname': ['Mary', 'Joseph'],
                    'drink': ['wine', 'beer']},
                   columns=['cusname', 'drink'])
df2
# Out:
#   cusname drink
# 0    Mary  wine
# 1  Joseph  beer

# %% [markdown]
# a) Combine the information into a single DataFrame using inner merge.

# %%
#your solution
pd.merge(df1, df2, left_on='name', right_on='cusname', how='inner')
# Out:
#    name   food cusname drink
# 0  Mary  bread    Mary  wine

# %% [markdown]
# b) Combine the information into a single DataFrame using left merge.

# %%
#your solution
pd.merge(df1, df2, left_on='name', right_on='cusname', how='left')
# Out:
#     name   food cusname drink
# 0  Peter   fish     NaN   NaN
# 1   Paul  beans     NaN   NaN
# 2   Mary  bread    Mary  wine

# %% [markdown]
# c) There is a pandas function named `join()` which works similarly to `merge()`. Research on the `join()` function. Can the `join()` function be used to answer parts (a) and (b)? If yes, show how it can be done, if not, explain why.

# %% [markdown]
# No, they have different ons. join uses index for joining whereas merge uses common columns

# %% [markdown]
# Hence, summarize the similarities and differences between `join()` and `merge()`.

# %% [markdown]
# Similarity: Both functions are using for merging 2 dataframes
# Differeneces: Merge does inner join by default, whereas join uses left join. join uses index for joining whereas merge uses common columns

# %% [markdown]
# ### Q4

# %% [markdown]
# Complete the following questions using the sample DataFrame given:

# %%
import numpy as np
df1 = pd.DataFrame({'fruit': ['apple', 'banana', 'orange'] * 3,
                    'weight': ['high', 'medium', 'low'] * 3,
                    'price': np.random.randint(0, 15, 9)})
df1
# Out:
#     fruit  weight  price
# 0   apple    high      8
# 1  banana  medium     10
# 2  orange     low     12
# 3   apple    high     13
# 4  banana  medium      2
# 5  orange     low     14
# 6   apple    high      1
# 7  banana  medium     14
# 8  orange     low      7

# %%
df2 = pd.DataFrame({'fruit': ['apple', 'orange', 'pine'] * 2,
                    'kilo': ['high', 'low'] * 3,
                    'price': np.random.randint(0, 15, 6)})
df2
# Out:
#     fruit  kilo  price
# 0   apple  high      5
# 1  orange   low      9
# 2    pine  high      3
# 3   apple   low      5
# 4  orange  high     13
# 5    pine   low      9

# %% [markdown]
# a) Combine the data in the two dataframes using `concat()` and reset the index for the new dataframe.

# %%
#your solution
pd.concat([df1, df2], ignore_index=True)
# Out:
#      fruit  weight  price  kilo
# 0    apple    high     12   NaN
# 1   banana  medium      8   NaN
# 2   orange     low      7   NaN
# 3    apple    high      4   NaN
# 4   banana  medium      3   NaN
# 5   orange     low      1   NaN
# 6    apple    high     13   NaN
# 7   banana  medium      3   NaN
# 8   orange     low      6   NaN
# 9    apple     NaN      8  high
# 10  orange     NaN     10   low
# 11    pine     NaN      3  high
# 12   apple     NaN      1   low
# 13  orange     NaN      3  high
# 14    pine     NaN     14   low

# %% [markdown]
# b) Combine the data in the two dataframes using `concat()` and group them using keys `Data A` and `Data B`.

# %%
#your solution
df = pd.concat([df1, df2], keys=['Data A', 'Data B'])
df
# Out:
#            fruit  weight  price  kilo
# Data A 0   apple    high     12   NaN
#        1  banana  medium      8   NaN
#        2  orange     low      7   NaN
#        3   apple    high      4   NaN
#        4  banana  medium      3   NaN
#        5  orange     low      1   NaN
#        6   apple    high     13   NaN
#        7  banana  medium      3   NaN
#        8  orange     low      6   NaN
# Data B 0   apple     NaN      8  high
#        1  orange     NaN     10   low
#        2    pine     NaN      3  high
#        3   apple     NaN      1   low
#        4  orange     NaN      3  high
#        5    pine     NaN     14   low

# %% [markdown]
# Using the combined dataframe from above, show all oranges from Data B.

# %%
#your solution
df.loc['Data B'].loc[df.loc['Data B']['fruit'] == 'orange']
# Out:
#     fruit weight  price  kilo
# 1  orange    NaN     10   low
# 4  orange    NaN      3  high

# %% [markdown]
# c) Combine the data in the two dataframes using `concat()` horizontally.

# %%
#your solution
pd.concat([df1,df2],axis=1)
# Out:
#     fruit  weight  price   fruit  kilo  price
# 0   apple    high     12   apple  high    8.0
# 1  banana  medium      8  orange   low   10.0
# 2  orange     low      7    pine  high    3.0
# 3   apple    high      4   apple   low    1.0
# 4  banana  medium      3  orange  high    3.0
# 5  orange     low      1    pine   low   14.0
# 6   apple    high     13     NaN   NaN    NaN
# 7  banana  medium      3     NaN   NaN    NaN
# 8  orange     low      6     NaN   NaN    NaN

# %% [markdown]
# d) There is a pandas function named `append()` which works similarly to `concat()`. Research on the `append()` function. Can the `append()` function be used to answer parts (a) to (c)? If yes, show how it can be done, if not, explain why.

# %% [markdown]
# No, as it only works for a). This is a append can only append rows

# %%
df1.append(df2)
# Out:
# C:\Users\Mahir\AppData\Local\Temp\ipykernel_3708\3062608662.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1.append(df2)
#     fruit  weight  price  kilo
# 0   apple    high      8   NaN
# 1  banana  medium     10   NaN
# 2  orange     low     12   NaN
# 3   apple    high     13   NaN
# 4  banana  medium      2   NaN
# 5  orange     low     14   NaN
# 6   apple    high      1   NaN
# 7  banana  medium     14   NaN
# 8  orange     low      7   NaN
# 0   apple     NaN      5  high
# 1  orange     NaN      9   low
# 2    pine     NaN      3  high
# 3   apple     NaN      5   low
# 4  orange     NaN     13  high
# 5    pine     NaN      9   low

# %% [markdown]
# Hence, summarize the similarities and differences between `append()` and `concat()`.

# %% [markdown]
# Similarities: Both of them append rows
# Differences: concat can also appen horizontally ans accept the keys for mu

# %% [markdown]
# ### Q5

# %% [markdown]
# There is no inbuilt insert function in pandas to insert a row of data.
# Write your own `insertRow()` function to allow a user to insert a row of data into a pandas dataframe.
# You are NOT allowed to use the 2 methods described in the notes, and not allowed to use any for loops in this question.

# %%
def insertRow(df, index, data):
    return pd.concat([df[0: index], data,df[index : ]], ignore_index = True)

# %%
#Test your code here
insertRow(df1, 0, df2)
# Out:
#      fruit  weight  price  kilo
# 0    apple     NaN      8  high
# 1   orange     NaN     10   low
# 2     pine     NaN      3  high
# 3    apple     NaN      1   low
# 4   orange     NaN      3  high
# 5     pine     NaN     14   low
# 6    apple    high     12   NaN
# 7   banana  medium      8   NaN
# 8   orange     low      7   NaN
# 9    apple    high      4   NaN
# 10  banana  medium      3   NaN
# 11  orange     low      1   NaN
# 12   apple    high     13   NaN
# 13  banana  medium      3   NaN
# 14  orange     low      6   NaN

# %%
insertRow(df2, 5, df1)
# Out:
#      fruit  kilo  price  weight
# 0    apple  high      8     NaN
# 1   orange   low     10     NaN
# 2     pine  high      3     NaN
# 3    apple   low      1     NaN
# 4   orange  high      3     NaN
# 5    apple   NaN     12    high
# 6   banana   NaN      8  medium
# 7   orange   NaN      7     low
# 8    apple   NaN      4    high
# 9   banana   NaN      3  medium
# 10  orange   NaN      1     low
# 11   apple   NaN     13    high
# 12  banana   NaN      3  medium
# 13  orange   NaN      6     low
# 14    pine   low     14     NaN
